# %%
import sys
#############################################
import warnings
warnings.filterwarnings("ignore")
#############################################
sys.path.insert(1, '/media/BINGODATA1/ComponentSeparation//beam_analyzes/scripts')
import handling_data          as hdata

# %%
output_info = {"pathdir_HI" :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI256',
               "pathdir_N"  :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/WN256',
               "realization": 'all',
               "pathdir_FG" :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/FG256',
               "nameFG"     :'FG_I_256_980mhz1260mhz_30bins_full_L0.fits',
               "pathdir_PL" : None,#'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/PL512',
               "namePL"     : None, #'PL_QU_512_980mhz1260mhz_30bins_full_2eQ_1eU_L0.fits',
               "apply_mask" : True,
               "pathdir_M"    :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/M256',
               "nameM"        :'mask_256_5degC2apod_20fgcut.fits',
               "apply_beam"   : True, 
               "type_beam"    :'gaussian',
               "type_fwhm"    :'fixed',
               "if_fwhm_fixed": 0.667,
               "main_dish_diameter": 40,
               "lmax"         : None,
               "theta_range"  : None,
               'new_nside'    : 256,
               'output_dir'   :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1',
               'clear_output_dir': False,
               'first_name'   :'BINGO',
               'add_info'     : None,#'2eQ_1eU'
               'pl_position'  : 0
              }

# %%
hdata.save_FITS_newformat_observed(output_info)
# Out:
# Checking output directory...
# Output directory ready.
#
# Changing dimensions...
# Realizations to be saved: ['0001' '0002' '0003' '0004' '0005' '0006' '0007' '0008' '0009' '0010'
#  '0011' '0012' '0013' '0014' '0015' '0016' '0017' '0018' '0019' '0020'
#  '0021' '0022' '0023' '0024' '0025' '0026' '0027' '0028' '0029' '0030'
#  '0031' '0032' '0033' '0034' '0035' '0036' '0037' '0038' '0039' '0040'
#  '0041' '0042' '0043' '0044' '0045' '0046' '0047' '0048' '0049' '0050'
#  '0051' '0052' '0053' '0054' '0055' '0056' '0057' '0058' '0059' '0060'
#  '0061' '0062' '0063' '0064' '0065' '0066' '0067' '0068' '0069' '0070'
#  '0071' '0072' '0073' '0074' '0075' '0076' '0077' '0078' '0079' '0080'
#  '0081' '0082' '0083' '0084' '0085' '0086' '0087' '0088' '0089' '0090'
#  '0091' '0092' '0093' '0094' '0095' '0096' '0097' '0098' '0099' '0100']
#
#
# Building maps of L0001...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0001.fits
# Saved.
#
# Building maps of L0002...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0002.fits
# Saved.
#
# Building maps of L0003...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0003.fits
# Saved.
#
# Building maps of L0004...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0004.fits
# Saved.
#
# Building maps of L0005...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0005.fits
# Saved.
#
# Building maps of L0006...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0006.fits
# Saved.
#
# Building maps of L0007...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0007.fits
# Saved.
#
# Building maps of L0008...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0008.fits
# Saved.
#
# Building maps of L0009...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0009.fits
# Saved.
#
# Building maps of L0010...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0010.fits
# Saved.
#
# Building maps of L0011...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0011.fits
# Saved.
#
# Building maps of L0012...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0012.fits
# Saved.
#
# Building maps of L0013...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0013.fits
# Saved.
#
# Building maps of L0014...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0014.fits
# Saved.
#
# Building maps of L0015...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0015.fits
# Saved.
#
# Building maps of L0016...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0016.fits
# Saved.
#
# Building maps of L0017...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0017.fits
# Saved.
#
# Building maps of L0018...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0018.fits
# Saved.
#
# Building maps of L0019...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0019.fits
# Saved.
#
# Building maps of L0020...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0020.fits
# Saved.
#
# Building maps of L0021...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0021.fits
# Saved.
#
# Building maps of L0022...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0022.fits
# Saved.
#
# Building maps of L0023...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0023.fits
# Saved.
#
# Building maps of L0024...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0024.fits
# Saved.
#
# Building maps of L0025...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0025.fits
# Saved.
#
# Building maps of L0026...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0026.fits
# Saved.
#
# Building maps of L0027...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0027.fits
# Saved.
#
# Building maps of L0028...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0028.fits
# Saved.
#
# Building maps of L0029...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0029.fits
# Saved.
#
# Building maps of L0030...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0030.fits
# Saved.
#
# Building maps of L0031...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0031.fits
# Saved.
#
# Building maps of L0032...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0032.fits
# Saved.
#
# Building maps of L0033...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0033.fits
# Saved.
#
# Building maps of L0034...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0034.fits
# Saved.
#
# Building maps of L0035...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0035.fits
# Saved.
#
# Building maps of L0036...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0036.fits
# Saved.
#
# Building maps of L0037...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0037.fits
# Saved.
#
# Building maps of L0038...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0038.fits
# Saved.
#
# Building maps of L0039...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0039.fits
# Saved.
#
# Building maps of L0040...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0040.fits
# Saved.
#
# Building maps of L0041...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0041.fits
# Saved.
#
# Building maps of L0042...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0042.fits
# Saved.
#
# Building maps of L0043...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0043.fits
# Saved.
#
# Building maps of L0044...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0044.fits
# Saved.
#
# Building maps of L0045...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0045.fits
# Saved.
#
# Building maps of L0046...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0046.fits
# Saved.
#
# Building maps of L0047...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0047.fits
# Saved.
#
# Building maps of L0048...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0048.fits
# Saved.
#
# Building maps of L0049...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0049.fits
# Saved.
#
# Building maps of L0050...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0050.fits
# Saved.
#
# Building maps of L0051...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0051.fits
# Saved.
#
# Building maps of L0052...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0052.fits
# Saved.
#
# Building maps of L0053...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0053.fits
# Saved.
#
# Building maps of L0054...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0054.fits
# Saved.
#
# Building maps of L0055...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0055.fits
# Saved.
#
# Building maps of L0056...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0056.fits
# Saved.
#
# Building maps of L0057...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0057.fits
# Saved.
#
# Building maps of L0058...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0058.fits
# Saved.
#
# Building maps of L0059...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0059.fits
# Saved.
#
# Building maps of L0060...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0060.fits
# Saved.
#
# Building maps of L0061...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0061.fits
# Saved.
#
# Building maps of L0062...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0062.fits
# Saved.
#
# Building maps of L0063...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0063.fits
# Saved.
#
# Building maps of L0064...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0064.fits
# Saved.
#
# Building maps of L0065...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0065.fits
# Saved.
#
# Building maps of L0066...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0066.fits
# Saved.
#
# Building maps of L0067...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0067.fits
# Saved.
#
# Building maps of L0068...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0068.fits
# Saved.
#
# Building maps of L0069...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0069.fits
# Saved.
#
# Building maps of L0070...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0070.fits
# Saved.
#
# Building maps of L0071...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0071.fits
# Saved.
#
# Building maps of L0072...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0072.fits
# Saved.
#
# Building maps of L0073...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0073.fits
# Saved.
#
# Building maps of L0074...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0074.fits
# Saved.
#
# Building maps of L0075...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0075.fits
# Saved.
#
# Building maps of L0076...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0076.fits
# Saved.
#
# Building maps of L0077...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0077.fits
# Saved.
#
# Building maps of L0078...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0078.fits
# Saved.
#
# Building maps of L0079...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0079.fits
# Saved.
#
# Building maps of L0080...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0080.fits
# Saved.
#
# Building maps of L0081...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0081.fits
# Saved.
#
# Building maps of L0082...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0082.fits
# Saved.
#
# Building maps of L0083...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0083.fits
# Saved.
#
# Building maps of L0084...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0084.fits
# Saved.
#
# Building maps of L0085...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0085.fits
# Saved.
#
# Building maps of L0086...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0086.fits
# Saved.
#
# Building maps of L0087...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0087.fits
# Saved.
#
# Building maps of L0088...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0088.fits
# Saved.
#
# Building maps of L0089...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0089.fits
# Saved.
#
# Building maps of L0090...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0090.fits
# Saved.
#
# Building maps of L0091...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0091.fits
# Saved.
#
# Building maps of L0092...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0092.fits
# Saved.
#
# Building maps of L0093...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0093.fits
# Saved.
#
# Building maps of L0094...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0094.fits
# Saved.
#
# Building maps of L0095...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0095.fits
# Saved.
#
# Building maps of L0096...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0096.fits
# Saved.
#
# Building maps of L0097...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0097.fits
# Saved.
#
# Building maps of L0098...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0098.fits
# Saved.
#
# Building maps of L0099...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0099.fits
# Saved.
#
# Building maps of L0100...
# Saving the file...
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/OBSERVED1/BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0100.fits
# Saved.
#
# Complete.

# %% [markdown]
# ### --------------

# %%
import healpy as hp
import healpy.newvisufunc as hpn
import astropy.io.fits as fits
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
from   IPython.display import clear_output
from matplotlib import cm
from matplotlib import rc
from copy import deepcopy as dcopy

# %%
filename = 'BINGO_I_256_980mhz1260mhz_30bins_partial_40arcminfixedG_beam_L0100.fits'
imap = hdata.getmap(dirpath_=output_info['output_dir'], filename_=filename, healpix_readingformat=False, hdu=1)

# %%
plt.figure(figsize=(20,8))
dec_min = -25.282 #from hitmap
dec_max =  -9.897
Dec_min = dec_min - 0.1
Dec_max = dec_max + 0.1
cmap    = "jet"

pos = [411,412,413,414]
ind = np.where(imap[0]<=0)[0]
for i, (jmap, jpos) in enumerate(zip([imap[0],imap[10],imap[20], imap[29]],pos)):
    jmap = dcopy(jmap)
    jmap[ind]=hp.UNSEEN
    hp.cartview(jmap, norm="hist", unit=None,  latra=[Dec_min,Dec_max], cmap=cmap, title=None,  sub=jpos )
