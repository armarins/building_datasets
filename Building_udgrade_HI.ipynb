# %%
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import os,sys,time
import numpy as np
import pandas as pd
import pymaster as nmt
import healpy as hp
import healpy.newvisufunc as hpn
import astropy.io.fits as fits
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
from   IPython.display import clear_output
from matplotlib import cm
from matplotlib import rc
from copy import deepcopy as dcopy
rc('text', usetex=True)
font = {'weight' : 'bold','size'   : 22}
matplotlib.rc('font', **font)

import astropy.units as u
import random
#############################################
sys.path.insert(1, '/media/BINGODATA1/ComponentSeparation/beam_analyzes/scripts')
#import beam_modelling         as model
import handling_data as hdata

# %%
output_info = {"pathdir_HI" :'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/WN512',
               "realization": 'all',
               'new_nside': 256,
               'output_dir':'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset_processed/WN512dg256',
               'clear_output_dir':True
              }

# %%
hdata.ud_grade_HImaps(output_info)
# Out:
# Checking output directory...
# Output directory ready.
#
# Changing dimensions...
# File 1 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0001.fits
# File 1 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0001.fits
#
# File 2 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0002.fits
# File 2 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0002.fits
#
# File 3 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0003.fits
# File 3 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0003.fits
#
# File 4 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0004.fits
# File 4 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0004.fits
#
# File 5 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0005.fits
# File 5 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0005.fits
#
# File 6 as input:  WN_None_512_980mhz1260mhz_30bins_partial_L0006.fits
# File 6 as output: WN_None_256_980mhz1260mhz_30bins_partial_L0006.fits
#
# ...
