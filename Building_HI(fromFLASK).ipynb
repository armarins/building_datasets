# %%
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import os,sys,time
import numpy as np
import pandas as pd
import pymaster as nmt
import healpy as hp
import healpy.newvisufunc as hpn
import astropy.io.fits as fits
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
from   IPython.display import clear_output
from matplotlib import cm
from matplotlib import rc
from copy import deepcopy as dcopy
rc('text', usetex=True)
font = {'weight' : 'bold','size'   : 22}
matplotlib.rc('font', **font)

import astropy.units as u
import random
#############################################
sys.path.insert(1, '/media/BINGODATA1/ComponentSeparation/beam_analyzes/scripts')
#import beam_modelling         as model
import handling_data as hdata

# %%
pathdir     = "/media/BINGODATA1/ComponentSeparation/MAPS/HI/flask_maps_512"#all fits files in path to be load and then saved
output_info = {"field":"HI", 
               "frequency":{"min":980,"max":1260,'nbands':30},
               "coverage":'full',
               'beam': {'model':None, 'fwhm':10}, 
               'stokes':'I',
               "freq_unit":"MHz", "stokes_unit":"mk", "fwhm_unit":"arcmin",
               "realization":'all',
               "output_dir":'/media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512',
               "clear_output_dir":True}

# %%
hdata.save_FITS_newformat(pathdir, output_info)
# Out:
# Realizations to be saved: ['0001' '0002' '0003' '0004' '0005' '0006' '0007' '0008' '0009' '0010'
#  '0011' '0012' '0013' '0014' '0015' '0016' '0017' '0018' '0019' '0020'
#  '0021' '0022' '0023' '0024' '0025' '0026' '0027' '0028' '0029' '0030'
#  '0031' '0032' '0033' '0034' '0035' '0036' '0037' '0038' '0039' '0040'
#  '0041' '0042' '0043' '0044' '0045' '0046' '0047' '0048' '0049' '0050'
#  '0051' '0052' '0053' '0054' '0055' '0056' '0057' '0058' '0059' '0060'
#  '0061' '0062' '0063' '0064' '0065' '0066' '0067' '0068' '0069' '0070'
#  '0071' '0072' '0073' '0074' '0075' '0076' '0077' '0078' '0079' '0080'
#  '0081' '0082' '0083' '0084' '0085' '0086' '0087' '0088' '0089' '0090'
#  '0091' '0092' '0093' '0094' '0095' '0096' '0097' '0098' '0099' '0100']
#
#
# Realization 0001
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0001.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0001.fits,,,
# Saved.
#
# Realization 0002
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0002.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0002.fits,,,
# Saved.
#
# Realization 0003
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0003.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0003.fits,,,
# Saved.
#
# Realization 0004
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0004.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0004.fits,,,
# Saved.
#
# Realization 0005
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0005.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0005.fits,,,
# Saved.
#
# Realization 0006
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0006.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0006.fits,,,
# Saved.
#
# Realization 0007
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0007.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0007.fits,,,
# Saved.
#
# Realization 0008
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0008.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0008.fits,,,
# Saved.
#
# Realization 0009
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0009.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0009.fits,,,
# Saved.
#
# Realization 0010
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0010.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0010.fits,,,
# Saved.
#
# Realization 0011
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0011.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0011.fits,,,
# Saved.
#
# Realization 0012
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0012.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0012.fits,,,
# Saved.
#
# Realization 0013
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0013.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0013.fits,,,
# Saved.
#
# Realization 0014
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0014.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0014.fits,,,
# Saved.
#
# Realization 0015
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0015.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0015.fits,,,
# Saved.
#
# Realization 0016
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0016.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0016.fits,,,
# Saved.
#
# Realization 0017
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0017.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0017.fits,,,
# Saved.
#
# Realization 0018
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0018.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0018.fits,,,
# Saved.
#
# Realization 0019
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0019.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0019.fits,,,
# Saved.
#
# Realization 0020
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0020.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0020.fits,,,
# Saved.
#
# Realization 0021
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0021.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0021.fits,,,
# Saved.
#
# Realization 0022
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0022.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0022.fits,,,
# Saved.
#
# Realization 0023
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0023.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0023.fits,,,
# Saved.
#
# Realization 0024
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0024.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0024.fits,,,
# Saved.
#
# Realization 0025
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0025.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0025.fits,,,
# Saved.
#
# Realization 0026
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0026.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0026.fits,,,
# Saved.
#
# Realization 0027
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0027.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0027.fits,,,
# Saved.
#
# Realization 0028
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0028.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0028.fits,,,
# Saved.
#
# Realization 0029
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0029.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0029.fits,,,
# Saved.
#
# Realization 0030
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0030.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0030.fits,,,
# Saved.
#
# Realization 0031
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0031.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0031.fits,,,
# Saved.
#
# Realization 0032
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0032.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0032.fits,,,
# Saved.
#
# Realization 0033
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0033.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0033.fits,,,
# Saved.
#
# Realization 0034
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0034.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0034.fits,,,
# Saved.
#
# Realization 0035
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0035.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0035.fits,,,
# Saved.
#
# Realization 0036
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0036.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0036.fits,,,
# Saved.
#
# Realization 0037
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0037.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0037.fits,,,
# Saved.
#
# Realization 0038
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0038.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0038.fits,,,
# Saved.
#
# Realization 0039
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0039.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0039.fits,,,
# Saved.
#
# Realization 0040
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0040.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0040.fits,,,
# Saved.
#
# Realization 0041
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0041.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0041.fits,,,
# Saved.
#
# Realization 0042
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0042.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0042.fits,,,
# Saved.
#
# Realization 0043
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0043.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0043.fits,,,
# Saved.
#
# Realization 0044
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0044.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0044.fits,,,
# Saved.
#
# Realization 0045
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0045.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0045.fits,,,
# Saved.
#
# Realization 0046
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0046.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0046.fits,,,
# Saved.
#
# Realization 0047
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0047.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0047.fits,,,
# Saved.
#
# Realization 0048
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0048.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0048.fits,,,
# Saved.
#
# Realization 0049
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0049.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0049.fits,,,
# Saved.
#
# Realization 0050
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0050.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0050.fits,,,
# Saved.
#
# Realization 0051
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0051.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0051.fits,,,
# Saved.
#
# Realization 0052
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0052.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0052.fits,,,
# Saved.
#
# Realization 0053
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0053.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0053.fits,,,
# Saved.
#
# Realization 0054
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0054.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0054.fits,,,
# Saved.
#
# Realization 0055
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0055.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0055.fits,,,
# Saved.
#
# Realization 0056
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0056.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0056.fits,,,
# Saved.
#
# Realization 0057
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0057.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0057.fits,,,
# Saved.
#
# Realization 0058
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0058.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0058.fits,,,
# Saved.
#
# Realization 0059
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0059.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0059.fits,,,
# Saved.
#
# Realization 0060
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0060.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0060.fits,,,
# Saved.
#
# Realization 0061
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0061.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0061.fits,,,
# Saved.
#
# Realization 0062
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0062.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0062.fits,,,
# Saved.
#
# Realization 0063
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0063.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0063.fits,,,
# Saved.
#
# Realization 0064
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0064.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0064.fits,,,
# Saved.
#
# Realization 0065
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0065.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0065.fits,,,
# Saved.
#
# Realization 0066
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0066.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0066.fits,,,
# Saved.
#
# Realization 0067
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0067.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0067.fits,,,
# Saved.
#
# Realization 0068
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0068.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0068.fits,,,
# Saved.
#
# Realization 0069
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0069.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0069.fits,,,
# Saved.
#
# Realization 0070
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0070.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0070.fits,,,
# Saved.
#
# Realization 0071
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0071.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0071.fits,,,
# Saved.
#
# Realization 0072
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0072.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0072.fits,,,
# Saved.
#
# Realization 0073
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0073.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0073.fits,,,
# Saved.
#
# Realization 0074
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0074.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0074.fits,,,
# Saved.
#
# Realization 0075
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0075.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0075.fits,,,
# Saved.
#
# Realization 0076
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0076.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0076.fits,,,
# Saved.
#
# Realization 0077
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0077.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0077.fits,,,
# Saved.
#
# Realization 0078
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0078.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0078.fits,,,
# Saved.
#
# Realization 0079
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0079.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0079.fits,,,
# Saved.
#
# Realization 0080
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0080.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0080.fits,,,
# Saved.
#
# Realization 0081
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0081.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0081.fits,,,
# Saved.
#
# Realization 0082
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0082.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0082.fits,,,
# Saved.
#
# Realization 0083
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0083.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0083.fits,,,
# Saved.
#
# Realization 0084
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0084.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0084.fits,,,
# Saved.
#
# Realization 0085
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0085.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0085.fits,,,
# Saved.
#
# Realization 0086
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0086.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0086.fits,,,
# Saved.
#
# Realization 0087
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0087.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0087.fits,,,
# Saved.
#
# Realization 0088
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0088.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0088.fits,,,
# Saved.
#
# Realization 0089
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0089.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0089.fits,,,
# Saved.
#
# Realization 0090
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0090.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0090.fits,,,
# Saved.
#
# Realization 0091
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0091.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0091.fits,,,
# Saved.
#
# Realization 0092
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0092.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0092.fits,,,
# Saved.
#
# Realization 0093
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0093.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0093.fits,,,
# Saved.
#
# Realization 0094
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0094.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0094.fits,,,
# Saved.
#
# Realization 0095
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0095.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0095.fits,,,
# Saved.
#
# Realization 0096
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0096.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0096.fits,,,
# Saved.
#
# Realization 0097
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0097.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0097.fits,,,
# Saved.
#
# Realization 0098
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0098.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0098.fits,,,
# Saved.
#
# Realization 0099
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0099.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0099.fits,,,
# Saved.
#
# Realization 0100
# Filename: HI_I_512_980mhz1260mhz_30bins_full_L0100.fits
# Saving in /media/BINGODATA1/ComponentSeparation/building_dataset/dataset/HI512/HI_I_512_980mhz1260mhz_30bins_full_L0100.fits,,,
# Saved.
#
# Completed.
